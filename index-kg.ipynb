# %% [markdown]
# To build the knowlege graph, create an empty dir called `kg` and copy the `extra/prompts/` in `kg`. Also put the text files in `kg/input`. So, the dir structure will look like following:
#
# ```
# |kg/
# |--> input/
# |--> prompts/
# ```

# %%
from graphrag.config.load_config import load_config
from pathlib import Path
from graphrag.api.index import build_index
import os

# %%
from dotenv import load_dotenv
load_dotenv(".env")

# %%
conf = load_config(Path("./"))

# %%
gr_conf = await build_index(config=conf)
